# %% [markdown]
# ## Image segmentation with CamVid

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# Done.

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/camvid/labels'),
#  PosixPath('/root/.fastai/data/camvid/images'),
#  PosixPath('/root/.fastai/data/camvid/valid.txt'),
#  PosixPath('/root/.fastai/data/camvid/codes.txt')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ## Subset classes

# %%
# path = Path('./data/camvid-small')

# def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
#     'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# src = (SegmentationItemList.from_folder(path)
#        .split_by_folder(valid='val')
#        .label_from_func(get_y_fn, classes=codes))

# bs=8
# data = (src.transform(get_transforms(), tfm_y=True)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/images/0016E5_06360.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_00720.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0006R0_f02250.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/labels/0016E5_05070_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0001TP_009750_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0016E5_05430_P.png')]

# %%
img_f = fnames[3]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
mask.data
# Out:
# tensor([[[ 4,  4,  4,  ..., 21, 21, 21],
#          [ 4,  4,  4,  ..., 21, 21, 21],
#          [ 4,  4,  4,  ..., 21, 21, 21],
#          ...,
#          [19, 19, 19,  ..., 17, 17, 17],
#          [19, 19, 19,  ..., 17, 17, 17],
#          [19, 19, 19,  ..., 17, 17, 17]]])

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %%
codes[4], codes[21], codes[19], codes[17]
# Out:
# ('Building', 'Sky', 'Sidewalk', 'Road')

# %% [markdown]
# ## Datasets

# %%
size = src_size//2
bs=8

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
data.train_ds[0][1].data.squeeze?
# Out:
# Object `data.squeeze` not found.

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:00, 93027126.70it/s]

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.31E-04

# %%
lr=3e-4

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# Total time: 38:42 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>2.271496</th>
#     <th>1.290852</th>
#     <th>0.690638</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.320038</th>
#     <th>0.873228</th>
#     <th>0.786568</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.917758</th>
#     <th>0.673029</th>
#     <th>0.830081</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.715399</th>
#     <th>0.582115</th>
#     <th>0.838521</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.642062</th>
#     <th>0.575216</th>
#     <th>0.840786</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.584995</th>
#     <th>0.543486</th>
#     <th>0.851095</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.564722</th>
#     <th>0.497278</th>
#     <th>0.856524</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.496671</th>
#     <th>0.445055</th>
#     <th>0.878713</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.490400</th>
#     <th>0.418050</th>
#     <th>0.882411</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.421834</th>
#     <th>0.350739</th>
#     <th>0.895060</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07

# %%
lrs = slice(1e-6,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='12', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       58.33% [7/12 27:58<19:59]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.361917</th>
#     <th>0.334427</th>
#     <th>0.898109</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.355893</th>
#     <th>0.329500</th>
#     <th>0.899231</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.355495</th>
#     <th>0.316890</th>
#     <th>0.904297</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.352683</th>
#     <th>0.329852</th>
#     <th>0.899796</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.341063</th>
#     <th>0.317890</th>
#     <th>0.902249</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.333581</th>
#     <th>0.320469</th>
#     <th>0.903265</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.334047</th>
#     <th>0.319062</th>
#     <th>0.902050</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='63' class='' max='75', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       84.00% [63/75 03:09<00:36 0.3220]
#     </div>

# %%
learn.save('stage-2');

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
size = src_size
bs=3

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# Total time: 20:31 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.366140</th>
#     <th>0.339497</th>
#     <th>0.908682</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.333278</th>
#     <th>0.304011</th>
#     <th>0.916702</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.326025</th>
#     <th>0.305404</th>
#     <th>0.919941</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.336885</th>
#     <th>0.321342</th>
#     <th>0.910933</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.326935</th>
#     <th>0.305589</th>
#     <th>0.919401</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.347779</th>
#     <th>0.333608</th>
#     <th>0.908895</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.328334</th>
#     <th>0.352358</th>
#     <th>0.905482</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.327277</th>
#     <th>0.387525</th>
#     <th>0.912187</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.291777</th>
#     <th>0.293065</th>
#     <th>0.918046</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.228348</th>
#     <th>0.257859</th>
#     <th>0.929750</th>
#   </tr>
# </table>

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(10, lrs)
# Out:
# Total time: 21:05 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.225999</th>
#     <th>0.254650</th>
#     <th>0.930782</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.216341</th>
#     <th>0.256007</th>
#     <th>0.930751</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.209800</th>
#     <th>0.255649</th>
#     <th>0.930709</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.203509</th>
#     <th>0.252857</th>
#     <th>0.931682</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.202308</th>
#     <th>0.258498</th>
#     <th>0.931308</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.200796</th>
#     <th>0.257311</th>
#     <th>0.931915</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.204560</th>
#     <th>0.251486</th>
#     <th>0.933218</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.192893</th>
#     <th>0.254977</th>
#     <th>0.932786</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.189505</th>
#     <th>0.258091</th>
#     <th>0.932555</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.190156</th>
#     <th>0.256064</th>
#     <th>0.933315</th>
#   </tr>
# </table>

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))

# %% [markdown]
# ## fin
